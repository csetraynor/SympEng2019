# %%
import pandas as pd
import numpy as np

path = '/home/mtr/Downloads/lusc_tcga_clinical_data.tsv'
df = pd.read_csv(path, sep="\t")   # read .tsv file into memory

a = df.values  # access the numpy array containing values

# %%
print(a.shape)
print(a)
# Out:
# (511, 111)
# [['lusc_tcga' 'TCGA-18-3406' 'TCGA-18-3406-01' ... 'Lung' 'A' 'Dead']
#  ['lusc_tcga' 'TCGA-18-3407' 'TCGA-18-3407-01' ... 'Lung' 'A' 'Dead']
#  ['lusc_tcga' 'TCGA-18-3408' 'TCGA-18-3408-01' ... 'Lung' 'A' 'Dead']
#  ...
#  ['lusc_tcga' 'TCGA-O2-A5IB' 'TCGA-O2-A5IB-01' ... 'Lung' 'A' 'Dead']
#  ['lusc_tcga' 'TCGA-O2-A5IC' 'TCGA-O2-A5IC-01' ... nan 'A' nan]
#  ['lusc_tcga' 'TCGA-XC-AA0X' 'TCGA-XC-AA0X-01' ... 'Lung' 'A' 'Dead']]

# %%
df
# Out:
#       Study ID    Patient ID        Sample ID  Diagnosis Age  \
# 0    lusc_tcga  TCGA-18-3406  TCGA-18-3406-01           67.0
# 1    lusc_tcga  TCGA-18-3407  TCGA-18-3407-01           72.0
# 2    lusc_tcga  TCGA-18-3408  TCGA-18-3408-01           77.0
# 3    lusc_tcga  TCGA-18-3409  TCGA-18-3409-01           74.0
# 4    lusc_tcga  TCGA-18-3410  TCGA-18-3410-01           81.0
# 5    lusc_tcga  TCGA-18-3411  TCGA-18-3411-01           63.0
# 6    lusc_tcga  TCGA-18-3412  TCGA-18-3412-01           52.0
# 7    lusc_tcga  TCGA-18-3414  TCGA-18-3414-01           73.0
# 8    lusc_tcga  TCGA-18-3415  TCGA-18-3415-01           77.0
# 9    lusc_tcga  TCGA-18-3416  TCGA-18-3416-01           83.0
# 10   lusc_tcga  TCGA-18-3417  TCGA-18-3417-01           65.0
# 11   lusc_tcga  TCGA-18-3419  TCGA-18-3419-01           73.0
# 12   lusc_tcga  TCGA-18-3421  TCGA-18-3421-01           65.0
# 13   lusc_tcga  TCGA-18-4083  TCGA-18-4083-01           63.0
# ...

# %%
fga = df['Fraction Genome Altered'].values

# %%
fga
fga.shape
# Out:
# (511,)

# %%
fga_clean = fga[~np.isnan(fga)]

# %%
y = fga_clean
y.shape
# Out:
# (501,)
